# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drive/My Drive/Colab Notebooks/data/upload_DJIA_table.csv')

print(df.isnull().values.any())

print(df.shape)
# Out:
# False
# (1989, 9)

# %%
df.head()
# Out:
#         Date         Open         High  ...    Adj Close  sentiment_score  Topic
# 0   8/8/2008  11432.08984  11759.95996  ...  11734.32031         0.708408     18
# 1  8/11/2008  11729.66992  11867.11035  ...  11782.34961         0.982830     12
# 2  8/12/2008  11781.70020  11782.34961  ...  11642.46973         0.935311     12
# 3  8/13/2008  11632.80957  11633.78027  ...  11532.95996         0.721639     12
# 4  8/14/2008  11532.07031  11718.28027  ...  11615.92969         0.971837     18
#
# [5 rows x 9 columns]

# %%
for col in df.columns: 
  sns.histplot(df[col])
  plt.show()

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
